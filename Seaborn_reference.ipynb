# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dfh = pd.read_csv('train.csv', index_col='Id') #loading train data 
dfs=pd.read_csv('spotify.csv')
dft=pd.read_csv('titanic_train.csv')
dfshort=pd.read_csv('titanic-short.csv')
dff=sns.load_dataset('flights')

# %% [markdown]
# ## Generic Commands

# %% [markdown]
# #### Plot Size

# %%
plt.figure(figsize=(9,9))

# %% [markdown]
# ####  Axis Name

# %%
plt.ylabel('Axis name X')
plt.xlabel('Axis name y')

# %% [markdown]
# ##### Show plot for each iteration

# %%
plt.show() #application below

# %%
for i in train.columns:
    sns.histplot(train[i])
    plt.show()

# %% [markdown]
# ## Sample Data Loading

# %%
dft.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
dfs.head(5)
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
temp=dfs['Date'].str.split('-',expand=True)
temp
# Out:
#         0   1   2
# 0    2017  01  06
# 1    2017  01  07
# 2    2017  01  08
# 3    2017  01  09
# 4    2017  01  10
# ..    ...  ..  ..
# 361  2018  01  05
# 362  2018  01  06
# 363  2018  01  07
# 364  2018  01  08
# 365  2018  01  09
#
# [366 rows x 3 columns]

# %%
dfs['year']=temp[0]
dfs['month']=temp[1]
dfs['ym']=temp[0]+temp[1]

# %%
dfs.head(2)
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
#
#    Unforgettable  year month      ym
# 0            NaN  2017    01  201701
# 1            NaN  2017    01  201701

# %%
dfs.set_index(dfs['Date'],inplace=True)

# %%
g=dfs.groupby(['ym'])
p=g['Despacito'].mean()

# %% [markdown]
# # PLOTS

# %% [markdown]
# #### LINE PLOTS . its a univariate quantative

# %%
dfs.head(2)
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN

# %%
sns.lineplot(data=dfs[ 'Shape of You'],)
# Out:
# <AxesSubplot:ylabel='Shape of You'>

# %%
plot=sns.lineplot(data=p)
#plot.set_xticklabels(plot.get_xticklabels(), rotation=30);

# %%
sns.lineplot(data=dfs[[ 'Shape of You', 'Despacito','Something Just Like This']])
# Out:
# <AxesSubplot:>

# %% [raw]
# sns.lineplot(data=dfs)

# %% [markdown]
# #### BAR CHART  COUNT PLOT - Two features

# %%
countplot plots the count of the number of records by category
barplot plots a value or metric for each category (by default, barplot plots the mean of a variable, by category)

# %% [raw]
# Bar chart need two features ,X axis is catagory , and y axis is a quantitative.
# it will sum the quantitative feature wrt each category and shown wrt ratio.
# If it is a catagorical label encoded with number, then the sum of all the labels will come
# ie in titanic if y is survived it will add the 0s and 1s, so effectively we will ge the ratio of
# survived between the class in the catagory feature in x

# %%
sns.barplot(x='Gender',y='Survived',data=dft)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Survived'>

# %% [raw]
# Hue is to add one more catagorical feature in the x axis,

# %%
sns.barplot(x='Gender',y='Survived',hue='Embarked',data=dft)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Survived'>

# %% [markdown]
# #### Combination of Bar plot and Facegrid - Cat plot -4 features

# %%
g = sns.catplot(x="Gender", y="Survived",
                hue="Pclass", col="Embarked",
                data=dft, kind="bar",
                height=4, aspect=.7);

# %%
sns.barplot(x='Embarked',y='Fare',hue='Pclass',data=dft)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Fare'>

# %% [markdown]
# #### BarPlot with Three Variable

# %%
sns.barplot(x='Gender',y='Survived',hue='Pclass',data=dft)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Survived'>

# %% [markdown]
# ###### below example is same as countplot

# %%
dft['Survived'].value_counts().index
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
dft['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.barplot(dft['Survived'].value_counts().index,dft['Survived'].value_counts()).set_title('Survi')
# Out:
# C:\Users\kiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Survi')

# %% [markdown]
# #### COUNT PLOT

# %%
plot=sns.countplot(x='Survived',data=dft)

# %%
plot=sns.countplot(x='Exterior1st',data=dfh)
plot.set_xticklabels(plot.get_xticklabels(), rotation=45);

# %% [markdown]
# #### Box plot with Quantitative

# %% [raw]
# In boxplot it will taker a quantitatie feature and plot with median(50percentile),
# 75 percentile/25percentile.
# If we add a catagorical feature then it will give that quantitative feature spread wrt each class
# in that catagorical feature

# %%
boxplot=sns.boxplot(x='Fare',data=dft,)

# %%
boxplot=sns.boxplot(x='Pclass',y='Fare',data=dft,)

# %%
boxplot=sns.boxplot(x='LotArea',data=dfh,)

# %% [markdown]
# #### multi  Box plot with a catatory and quantitative spread wrt each class

# %%
boxplot=sns.boxplot(x='Exterior1st',y='SalePrice',data=dfh,)
boxplot.set_xticklabels(boxplot.get_xticklabels(), rotation=90);

# %% [raw]
# If we are ploting a catagorical against a Quantitative data , it will give the mean of that quantitative
# wrt each class in that catagorical feature
# Here we have catagory of Exterist and Sales is the Quatitative.so we will get the avg sales price
# for each catagory class

# %% [markdown]
# ### Violin Plot

# %% [raw]
# It is the combination of box plot and KDE plot

# %%
sns.violinplot( x='SalePrice',data=dfh)  #can add hue for three variable
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
sns.violinplot(x='SaleCondition', y='SalePrice',data=dfh)  #can add hue for three variable
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %%
sns.violinplot(y='Fare', x='Gender',hue='Embarked',data=dft,order=["female", "male"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Fare'>

# %% [markdown]
# Most number of hightest paid people are from C and the lease paid are from Q, so more chance of survival are from C

# %%
sns.violinplot(y='Fare', x='Embarked',hue='Pclass',data=dft)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Fare'>

# %% [markdown]
# #### DISTRIBUTION PLOT  -Univariate Quantitative

# %%
dft['log']=np.log(dft['Fare'])

# %%
sns.distplot(dft['Fare'],kde=True)  #can use binsize or bin
# Out:
# C:\Users\kiran\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
sns.histplot(df['Fare'])

# %%
from scipy.stats import norm
sns.distplot(dft['Fare'],fit=norm,kde=False)
# Out:
# C:\Users\kiran\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare'>

# %%
sns.distplot(dfh['LotArea'],kde=True)
# Out:
# C:\Users\kiran\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %%
sns.histplot(dfh['LotArea'],kde=True,binwidth=1000)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Count'>

# %% [markdown]
# ## BIVARIATE  / MULTIVARIATE

# %% [markdown]
# #### Scatter plot  -Three variable - two Quantitative and one catagorical

# %%
sns.scatterplot(x='LotArea',y='SalePrice',data=dfh)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.scatterplot(x='LotArea',y='SalePrice',hue='Street',data=dfh)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %% [markdown]
# #### Scatter Plot - with Regression line

# %%
sns.regplot(x='LotArea',y='SalePrice',data=dfh)   ##can add hue for three variable
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %% [markdown]
# #### Scatter -Three variable with Reg Line

# %%
sns.lmplot(x='LotArea',y='SalePrice',hue='Street',data=dfh)   #

# %% [markdown]
# ## Categorical scatter plot,

# %%
sns.swarmplot(x='SaleCondition', y='SalePrice',data=dfh)  ##can add hue for three variable
# Out:
# C:\Users\kiran\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 85.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\kiran\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\kiran\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %%
sns.stripplot(x='SaleCondition', y='SalePrice',data=dfh)  ##can add hue for three variable
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %%
sns.stripplot(x='SaleCondition', y='SalePrice',data=dfh,jitter=False)  ##can add hue for three variable
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %% [markdown]
# ## Heat Map

# %% [markdown]
# ##### Heat map to check the correlation

# %%
c_mx=c_df.corr()  #getting the correlation
c_mx

# %%
sns.heatmap(dft.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dft.corr(),cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dft.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dft.corr(),cmap='Blues',annot=True,cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dft.corr(),cmap='Blues',annot=True,cbar=False,linecolor='white',linewidth='4')
# Out:
# <AxesSubplot:>

# %%
flights_pivot= dff.pivot_table(index='month',columns='year',values='passengers')
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights_pivot,cmap='Blues')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ##### To get the Null Values

# %%
sns.heatmap(dft.isnull(),yticklabels=False,cbar=False,cmap='viridis')  #cmap is for color coding
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Distributions

# %%
sns.distplot(a=dft['Fare'],kde=False)
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
sns.distplot(a=dft['Fare'],kde=True)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
sns.distplot(a=dft['Fare'],kde=False,bins=3)
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
  sns.histplot(dft['Fare'],kde=False,binwidth=25)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %% [markdown]
# ### Grid Plots

# %%
dfh.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
g = sns.FacetGrid(dft, col='Embarked')
g = g.map(sns.histplot, "Age")

# %% [markdown]
# #### Removing Outliers from the Data

# %%
filt =df['LotArea']<df['LotArea'].quantile(0.96)
df_sub=df.loc[filt]

sns.regplot(x='LotArea',y='SalePrice',data=df_sub)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %% [markdown]
# ##### SubPlots

# %%
c=[ 'LotArea','GarageArea',' GrLivArea','KitchenAbvGr']

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
for i in range(0,len(c)):
    rows=i//2
    cols=i%2
    ax=axs[rows,cols]
    plot=sns.regplot(x=c[i],y='SalePrice',data=df,ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' GrLivArea'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-bae7520b0154> in <module>
#       4     cols=i%2
# ...

# %%
dfp.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
dfp= sns.load_dataset("penguins")
dfp.head(3)
dfp['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")

# %%
sns.displot(data=penguins, x="flipper_length_mm", col="species")

# %%
columns = ['Pclass', 'Sex','Embarked','SibSp', 'Parch','Survived']

plt.figure(figsize=(16, 14))
sns.set(font_scale= 1.2)
sns.set_style('ticks')

for i, feature in enumerate(columns):
    plt.subplot(3, 3, i+1)
    sns.countplot(data=dft, x=feature, hue='Survived',palette='Paired')

# %%
plot=sns.barplot(x='Exterior1st',y='SalePrice',data=dfh)
plot.set_xticklabels(plot.get_xticklabels(), rotation=60);

# %%
ax = sns.boxplot(x='SaleCondition', y='SalePrice', data=dfh, whis=np.inf)
ax=sns.stripplot(x='SaleCondition', y='SalePrice',data=dfh)
